# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemanthk408/Multiple-Disease-Prediction/blob/main/Multiple_Disease_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # diecase

# %%
df=pd.read_csv('/content/indian_liver_patient - indian_liver_patient.csv')
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# 1                          64                         100             7.5
# 2                          60                          68             7.0
# 3                          14                          20             6.8
# 4                          27                          59             7.3
# ..                        ...                         ...             ...
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0        3.3                        0.90        1
# 1        3.2                        0.74        1
# 2        3.3                        0.89        1
# 3        3.4                        1.00        1
# 4        2.4                        0.40        1
# ..       ...                         ...      ...
# 578      1.6                        0.37        2
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
# 582      4.4                        1.50        2
#
# [583 rows x 11 columns]

# %%
#cateceri=("Gender","Dataset")
#contunius=("Age","Total_Bilirubin","Direct_Bilirubin","Alkaline_Phosphotase","Alamine_Aminotransferase","Aspartate_Aminotransferase","Total_Protiens","Albumin","Albumin_and_Globulin_Ratio")

# %%
df.nunique()
# Out:
# Age                            72
# Gender                          2
# Total_Bilirubin               113
# Direct_Bilirubin               80
# Alkaline_Phosphotase          263
# Alamine_Aminotransferase      152
# Aspartate_Aminotransferase    177
# Total_Protiens                 58
# Albumin                        40
# Albumin_and_Globulin_Ratio     69
# Dataset                         2
# dtype: int64

# %%
for i in df.select_dtypes(include='object').columns:
  print(i,df[i].unique())
# Out:
# Gender ['Female' 'Male']

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder()

# %%
df['Gender']=encoder.fit_transform(df[['Gender']])

# %%
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65     0.0              0.7               0.1                   187
# 1     62     1.0             10.9               5.5                   699
# 2     62     1.0              7.3               4.1                   490
# 3     58     1.0              1.0               0.4                   182
# 4     72     1.0              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60     1.0              0.5               0.1                   500
# 579   40     1.0              0.6               0.1                    98
# 580   52     1.0              0.8               0.2                   245
# 581   31     1.0              1.3               0.5                   184
# 582   38     1.0              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# 1                          64                         100             7.5
# 2                          60                          68             7.0
# 3                          14                          20             6.8
# 4                          27                          59             7.3
# ..                        ...                         ...             ...
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0        3.3                        0.90        1
# 1        3.2                        0.74        1
# 2        3.3                        0.89        1
# 3        3.4                        1.00        1
# 4        2.4                        0.40        1
# ..       ...                         ...      ...
# 578      1.6                        0.37        2
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
# 582      4.4                        1.50        2
#
# [583 rows x 11 columns]

# %%
df=pd.DataFrame(df)

# %%
# Calculate the A/G ratio using the given formula
df['Albumin_and_Globulin_Ratio'] =df['Albumin_and_Globulin_Ratio'].fillna(df['Albumin'] / (df['Total_Protiens'] - df['Albumin']))

# %%
df['Dataset']=df['Dataset'].map({1:1,2:0})

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
df.set_index('Age',inplace=True)

# %%
df.corr()
# Out:
#                               Gender  Total_Bilirubin  Direct_Bilirubin  \
# Gender                      1.000000         0.089291          0.100436
# Total_Bilirubin             0.089291         1.000000          0.874618
# Direct_Bilirubin            0.100436         0.874618          1.000000
# Alkaline_Phosphotase       -0.027496         0.206669          0.234939
# Alamine_Aminotransferase    0.082332         0.214065          0.233894
# Aspartate_Aminotransferase  0.080336         0.237831          0.257544
# Total_Protiens             -0.089121        -0.008099         -0.000139
# Albumin                    -0.093799        -0.222250         -0.228531
# Albumin_and_Globulin_Ratio -0.008400        -0.207360         -0.201315
# Dataset                     0.082416         0.220208          0.246046
#
#                             Alkaline_Phosphotase  Alamine_Aminotransferase  \
# Gender                                 -0.027496                  0.082332
# Total_Bilirubin                         0.206669                  0.214065
# Direct_Bilirubin                        0.234939                  0.233894
# Alkaline_Phosphotase                    1.000000                  0.125680
# Alamine_Aminotransferase                0.125680                  1.000000
# Aspartate_Aminotransferase              0.167196                  0.791966
# Total_Protiens                         -0.028514                 -0.042518
# Albumin                                -0.165453                 -0.029742
# Albumin_and_Globulin_Ratio             -0.236023                 -0.003996
# Dataset                                 0.184866                  0.163416
#
#                             Aspartate_Aminotransferase  Total_Protiens  \
# Gender                                        0.080336       -0.089121
# Total_Bilirubin                               0.237831       -0.008099
# Direct_Bilirubin                              0.257544       -0.000139
# Alkaline_Phosphotase                          0.167196       -0.028514
# Alamine_Aminotransferase                      0.791966       -0.042518
# Aspartate_Aminotransferase                    1.000000       -0.025645
# Total_Protiens                               -0.025645        1.000000
# Albumin                                      -0.085290        0.784053
# Albumin_and_Globulin_Ratio                   -0.071064        0.236079
# Dataset                                       0.151934       -0.035008
#
#                              Albumin  Albumin_and_Globulin_Ratio   Dataset
# Gender                     -0.093799                   -0.008400  0.082416
# Total_Bilirubin            -0.222250                   -0.207360  0.220208
# Direct_Bilirubin           -0.228531                   -0.201315  0.246046
# Alkaline_Phosphotase       -0.165453                   -0.236023  0.184866
# Alamine_Aminotransferase   -0.029742                   -0.003996  0.163416
# Aspartate_Aminotransferase -0.085290                   -0.071064  0.151934
# Total_Protiens              0.784053                    0.236079 -0.035008
# Albumin                     1.000000                    0.690168 -0.161388
# Albumin_and_Globulin_Ratio  0.690168                    1.000000 -0.164313
# Dataset                    -0.161388                   -0.164313  1.000000

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=350)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((466, 9), (117, 9), (466,), (117,))

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier().fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 9, 23],
#        [28, 57]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5641025641025641

# %%
from sklearn.ensemble import RandomForestClassifier
model1=RandomForestClassifier().fit(x_train,y_train)
y_pred=model1.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.41      0.46        32
#            1       0.79      0.86      0.82        85
#
#     accuracy                           0.74       117
#    macro avg       0.66      0.63      0.64       117
# weighted avg       0.72      0.74      0.72       117

# %%
from xgboost import XGBClassifier
model=XGBClassifier().fit(x_train,y_train)
y_pred=model.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.50      0.42        22
#            1       0.87      0.80      0.84        95
#
#     accuracy                           0.74       117
#    macro avg       0.62      0.65      0.63       117
# weighted avg       0.78      0.74      0.76       117

# %%
from sklearn.ensemble import AdaBoostClassifier
model4=AdaBoostClassifier().fit(x_train,y_train)
y_pred=model4.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.47      0.46        32
#            1       0.80      0.79      0.79        85
#
#     accuracy                           0.70       117
#    macro avg       0.63      0.63      0.63       117
# weighted avg       0.70      0.70      0.70       117

# %%
from sklearn.linear_model import SGDClassifier
liver_model6=SGDClassifier().fit(x_train,y_train)
y_pred=liver_model6.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        32
#            1       0.73      1.00      0.84        85
#
#     accuracy                           0.73       117
#    macro avg       0.36      0.50      0.42       117
# weighted avg       0.53      0.73      0.61       117
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.ensemble import ExtraTreesClassifier
liver_model=ExtraTreesClassifier().fit(x_train,y_train)
y_pred=liver_model.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.44      0.50        32
#            1       0.81      0.88      0.84        85
#
#     accuracy                           0.76       117
#    macro avg       0.69      0.66      0.67       117
# weighted avg       0.75      0.76      0.75       117

# %%
pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.13-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.5.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.1.3)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost->lazypredict) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.17.0)
# Downloading lazypredict-0.2.13-py2.py3-none-any.whl (12 kB)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.13

# %%
from lazypredict.Supervised import LazyClassifier
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=.2,random_state =300)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(x_train, x_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████| 32/32 [00:02<00:00, 12.58it/s]
# [LightGBM] [Info] Number of positive: 321, number of negative: 145
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000928 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 498
# [LightGBM] [Info] Number of data points in the train set: 466, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.688841 -> initscore=0.794707
# [LightGBM] [Info] Start training from score 0.794707
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# BaggingClassifier                  0.73               0.69     0.69      0.75
# ExtraTreesClassifier               0.80               0.69     0.69      0.81
# GaussianNB                         0.49               0.67     0.67      0.52
# AdaBoostClassifier                 0.71               0.66     0.66      0.73
# DecisionTreeClassifier             0.72               0.65     0.65      0.74
# SGDClassifier                      0.62               0.64     0.64      0.66
# ExtraTreeClassifier                0.69               0.64     0.64      0.72
# RandomForestClassifier             0.77               0.63     0.63      0.77
# LGBMClassifier                     0.74               0.62     0.62      0.75
# NearestCentroid                    0.56               0.61     0.61      0.61
# QuadraticDiscriminantAnalysis      0.48               0.59     0.59      0.52
# NuSVC                              0.73               0.59     0.59      0.73
# BernoulliNB                        0.61               0.55     0.55      0.65
# LinearDiscriminantAnalysis         0.82               0.54     0.54      0.76
# LogisticRegression                 0.75               0.53     0.53      0.73
# LabelPropagation                   0.67               0.53     0.53      0.69
# LabelSpreading                     0.66               0.53     0.53      0.68
# LinearSVC                          0.77               0.53     0.53      0.74
# RidgeClassifier                    0.82               0.52     0.52      0.75
# RidgeClassifierCV                  0.82               0.52     0.52      0.75
# PassiveAggressiveClassifier        0.69               0.51     0.51      0.70
# CalibratedClassifierCV             0.80               0.51     0.51      0.74
# Perceptron                         0.74               0.51     0.51      0.72
# DummyClassifier                    0.81               0.50     0.50      0.73
# SVC                                0.81               0.50     0.50      0.73
# KNeighborsClassifier               0.70               0.48     0.48      0.69
#
#                                Time Taken
# Model
# BaggingClassifier                    0.06
# ExtraTreesClassifier                 0.30
# GaussianNB                           0.03
# AdaBoostClassifier                   0.16
# DecisionTreeClassifier               0.03
# SGDClassifier                        0.03
# ExtraTreeClassifier                  0.03
# RandomForestClassifier               0.38
# LGBMClassifier                       0.20
# NearestCentroid                      0.03
# QuadraticDiscriminantAnalysis        0.05
# NuSVC                                0.05
# BernoulliNB                          0.03
# LinearDiscriminantAnalysis           0.08
# LogisticRegression                   0.03
# LabelPropagation                     0.07
# LabelSpreading                       0.10
# LinearSVC                            0.04
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.03
# PassiveAggressiveClassifier          0.03
# CalibratedClassifierCV               0.09
# Perceptron                           0.03
# DummyClassifier                      0.04
# SVC                                  0.04
# KNeighborsClassifier                 0.04

# %%
import pickle

# %%
with(open('liver.pkl','wb')) as file:
  pickle.dump(liver_model,file)

# %%
pickle.dump(liver_model,open('liver.pkl','wb'))

# %% [markdown]
# #kidney_disease

# %%
df1=pd.read_csv('/content/kidney_disease - kidney_disease.csv')
df1
# Out:
#       id   age    bp   sg   al   su     rbc        pc         pcc          ba  \
# 0      0 48.00 80.00 1.02 1.00 0.00     NaN    normal  notpresent  notpresent
# 1      1  7.00 50.00 1.02 4.00 0.00     NaN    normal  notpresent  notpresent
# 2      2 62.00 80.00 1.01 2.00 3.00  normal    normal  notpresent  notpresent
# 3      3 48.00 70.00 1.00 4.00 0.00  normal  abnormal     present  notpresent
# 4      4 51.00 80.00 1.01 2.00 0.00  normal    normal  notpresent  notpresent
# ..   ...   ...   ...  ...  ...  ...     ...       ...         ...         ...
# 395  395 55.00 80.00 1.02 0.00 0.00  normal    normal  notpresent  notpresent
# 396  396 42.00 70.00 1.02 0.00 0.00  normal    normal  notpresent  notpresent
# 397  397 12.00 80.00 1.02 0.00 0.00  normal    normal  notpresent  notpresent
# 398  398 17.00 60.00 1.02 0.00 0.00  normal    normal  notpresent  notpresent
# 399  399 58.00 80.00 1.02 0.00 0.00  normal    normal  notpresent  notpresent
#
#      ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0    ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1    ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2    ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3    ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4    ...   35  7300  4.6   no   no   no  good   no   no            ckd
# ..   ...  ...   ...  ...  ...  ...  ...   ...  ...  ...            ...
# 395  ...   47  6700  4.9   no   no   no  good   no   no         notckd
# 396  ...   54  7800  6.2   no   no   no  good   no   no         notckd
# 397  ...   49  6600  5.4   no   no   no  good   no   no         notckd
# 398  ...   51  7200  5.9   no   no   no  good   no   no         notckd
# 399  ...   53  6800  6.1   no   no   no  good   no   no         notckd
#
# [400 rows x 26 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
column_mapping= {
    'bp': 'Blood Pressure',
    'sg': 'Specific Gravity',
    'al': 'Albumin',
    'su': 'Sugar',
    'rbc': 'Red Blood Cells',
    'pc': 'Pus Cells',
    'pcc': 'Pus Cell Clumps',
    'ba': 'Bacteria',
    'bgr': 'Blood Glucose Random',
    'bu': 'Blood Urea',
    'sc': 'Serum Creatinine',
    'sod': 'Sodium',
    'pot': 'Potassium',
    'hemo': 'Hemoglobin',
    'pcv': 'Packed Cell Volume',
    'wc': 'White Blood Cell Count',
    'rc': 'Red Blood Cell Count',
    'htn': 'Hypertension',
    'dm': 'Diabetes Mellitus',
    'cad': 'Coronary Artery Disease',
    'appet': 'Appetite',
    'pe': 'Pedal Edema',
    'ane': 'Anemia',
}
df1.rename(columns=column_mapping, inplace=True)

# %%
df1.fillna(method='bfill', inplace=True)

# %%
df1.drop(['id'], axis=1, inplace=True)

# %%
for i in df1.select_dtypes(include='object').columns:
  print(i,df1[i].unique())
# Out:
# Red Blood Cells ['normal' 'abnormal']
# Pus Cells ['normal' 'abnormal']
# Pus Cell Clumps ['notpresent' 'present']
# Bacteria ['notpresent' 'present']
# Packed Cell Volume ['44' '38' '31' '32' '35' '39' '36' '33' '29' '28' '16' '24' '37' '30'
#  '34' '40' '45' '27' '48' '?' '52' '14' '22' '18' '42' '17' '46' '23' '19'
#  '25' '41' '26' '15' '21' '43' '20' '47' '9' '49' '50' '53' '51' '54']
# White Blood Cell Count ['7800' '6000' '7500' '6700' '7300' '6900' '9600' '12100' '4500' '12200'
#  '11000' '3800' '11400' '5300' '9200' '6200' '8300' '8400' '10300' '9800'
#  '9100' '7900' '6400' '8600' '18900' '21600' '4300' '8500' '11300' '7200'
#  '7700' '14600' '6300' '7100' '11800' '9400' '5500' '5800' '13200' '12500'
#  '5600' '7000' '11900' '10400' '10700' '12700' '6800' '6500' '13600'
#  '10200' '9000' '14900' '8200' '15200' '5000' '16300' '12400' '10500'
#  '4200' '4700' '10900' '8100' '9500' '2200' '12800' '11200' '19100' '?'
#  '12300' '16700' '2600' '26400' '8800' '7400' '4900' '8000' '12000'
#  '15700' '4100' '5700' '11500' '5400' '10800' '9900' '5200' '5900' '9300'
#  '9700' '5100' '6600']
# Red Blood Cell Count ['5.2' '3.9' '4.6' '4.4' '5' '4' '3.7' '3.8' '3.4' '2.6' '2.8' '4.3' '3.2'
#  '3.6' '4.1' '4.9' '2.5' '4.2' '4.5' '3.1' '4.7' '3.5' '6' '2.1' '5.6'
#  '2.3' '2.9' '2.7' '8' '3.3' '3' '2.4' '4.8' '?' '5.4' '6.1' '6.2' '6.3'
#  '5.1' '5.8' '5.5' '5.3' '6.4' '5.7' '5.9' '6.5']
# Hypertension ['yes' 'no']
# Diabetes Mellitus ['yes' 'no']
# Coronary Artery Disease ['no' 'yes']
# Appetite ['good' 'poor']
# Pedal Edema ['no' 'yes']
# Anemia ['no' 'yes']
# classification ['ckd' 'notckd']

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder()

# %%
for i in df1.select_dtypes(include='object').columns:
  df1[i]=encoder.fit_transform(df1[[i]])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      400 non-null    float64
#  1   Blood Pressure           400 non-null    float64
#  2   Specific Gravity         400 non-null    float64
#  3   Albumin                  400 non-null    float64
#  4   Sugar                    400 non-null    float64
#  5   Red Blood Cells          400 non-null    float64
#  6   Pus Cells                400 non-null    float64
#  7   Pus Cell Clumps          400 non-null    float64
#  8   Bacteria                 400 non-null    float64
#  9   Blood Glucose Random     400 non-null    float64
#  10  Blood Urea               400 non-null    float64
#  11  Serum Creatinine         400 non-null    float64
#  12  Sodium                   400 non-null    float64
#  13  Potassium                400 non-null    float64
#  14  Hemoglobin               400 non-null    float64
#  15  Packed Cell Volume       400 non-null    float64
#  16  White Blood Cell Count   400 non-null    float64
#  17  Red Blood Cell Count     400 non-null    float64
#  18  Hypertension             400 non-null    float64
#  19  Diabetes Mellitus        400 non-null    float64
#  20  Coronary Artery Disease  400 non-null    float64
#  21  Appetite                 400 non-null    float64
#  22  Pedal Edema              400 non-null    float64
#  23  Anemia                   400 non-null    float64
#  24  classification           400 non-null    float64
# dtypes: float64(25)
# memory usage: 78.2 KB

# %%
a = df1.drop(['classification'], axis=1)
b = df1['classification']

# %%
from sklearn.model_selection import train_test_split
a_train,a_test,b_train,b_test=train_test_split(a,b,test_size=0.2)
a_train.shape,a_test.shape,b_train.shape,b_test.shape
# Out:
# ((320, 24), (80, 24), (320,), (80,))

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier().fit(a_train,b_train)
b_pred=model.predict(a_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
print(classification_report(b_test,b_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        49
#          1.0       1.00      1.00      1.00        31
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80

# %%
from sklearn.ensemble import RandomForestClassifier
model1=RandomForestClassifier().fit(a_train,b_train)
b_pred=model1.predict(a_test)
print(classification_report(b_test,b_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        49
#          1.0       1.00      1.00      1.00        31
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80

# %%
from xgboost import XGBClassifier
model3=XGBClassifier().fit(a_train,b_train)
b_pred=model3.predict(a_test)
print(classification_report(b_test,b_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        49
#          1.0       1.00      1.00      1.00        31
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80

# %%
with(open('kidney.pkl','wb')) as file:
  pickle.dump(model3,file)

# %% [markdown]
# #parkinsons

# %%
df3=pd.read_csv('/content/parkinsons - parkinsons.csv')
df3
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1       119.99        157.30         75.00            0.01
# 1    phon_R01_S01_2       122.40        148.65        113.82            0.01
# 2    phon_R01_S01_3       116.68        131.11        111.56            0.01
# 3    phon_R01_S01_4       116.68        137.87        111.37            0.01
# 4    phon_R01_S01_5       116.01        141.78        110.66            0.01
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2       174.19        230.98         94.26            0.00
# 191  phon_R01_S50_3       209.52        253.02         89.49            0.01
# 192  phon_R01_S50_4       174.69        240.00         74.29            0.01
# 193  phon_R01_S50_5       198.76        396.96         74.90            0.01
# 194  phon_R01_S50_6       214.29        260.28         77.97            0.01
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0                0.00      0.00      0.01        0.01          0.04
# 1                0.00      0.00      0.01        0.01          0.06
# 2                0.00      0.01      0.01        0.02          0.05
# 3                0.00      0.01      0.01        0.02          0.05
# 4                0.00      0.01      0.01        0.02          0.06
# ..                ...       ...       ...         ...           ...
# 190              0.00      0.00      0.00        0.01          0.04
# 191              0.00      0.00      0.00        0.01          0.03
# 192              0.00      0.01      0.01        0.02          0.02
# 193              0.00      0.00      0.00        0.01          0.02
# 194              0.00      0.00      0.00        0.01          0.02
#
#      MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  NHR  \
# 0                0.43          0.02          0.03      0.03         0.07 0.02
# 1                0.63          0.03          0.05      0.04         0.09 0.02
# 2                0.48          0.03          0.04      0.04         0.08 0.01
# 3                0.52          0.03          0.04      0.04         0.09 0.01
# 4                0.58          0.03          0.05      0.04         0.10 0.02
# ..                ...           ...           ...       ...          ...  ...
# 190              0.41          0.02          0.02      0.03         0.07 0.03
# 191              0.26          0.02          0.02      0.02         0.05 0.02
# 192              0.26          0.01          0.01      0.02         0.04 0.11
# 193              0.24          0.01          0.01      0.02         0.04 0.07
# 194              0.19          0.01          0.01      0.01         0.03 0.04
#
#       HNR  status  RPDE  DFA  spread1  spread2   D2  PPE
# 0   21.03       1  0.41 0.82    -4.81     0.27 2.30 0.28
# 1   19.09       1  0.46 0.82    -4.08     0.34 2.49 0.37
# 2   20.65       1  0.43 0.83    -4.44     0.31 2.34 0.33
# 3   20.64       1  0.43 0.82    -4.12     0.33 2.41 0.37
# 4   19.65       1  0.42 0.82    -3.75     0.23 2.33 0.41
# ..    ...     ...   ...  ...      ...      ...  ...  ...
# 190 19.52       0  0.45 0.66    -6.54     0.12 2.66 0.13
# 191 19.15       0  0.43 0.68    -6.20     0.13 2.78 0.17
# 192 17.88       0  0.41 0.66    -6.79     0.16 2.68 0.13
# 193 19.02       0  0.45 0.64    -6.74     0.21 2.14 0.12
# 194 21.21       0  0.46 0.66    -5.72     0.19 2.56 0.15
#
# [195 rows x 24 columns]

# %%
pd.set_option('display.max_columns',None)
df3
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1       119.99        157.30         75.00            0.01
# 1    phon_R01_S01_2       122.40        148.65        113.82            0.01
# 2    phon_R01_S01_3       116.68        131.11        111.56            0.01
# 3    phon_R01_S01_4       116.68        137.87        111.37            0.01
# 4    phon_R01_S01_5       116.01        141.78        110.66            0.01
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2       174.19        230.98         94.26            0.00
# 191  phon_R01_S50_3       209.52        253.02         89.49            0.01
# 192  phon_R01_S50_4       174.69        240.00         74.29            0.01
# 193  phon_R01_S50_5       198.76        396.96         74.90            0.01
# 194  phon_R01_S50_6       214.29        260.28         77.97            0.01
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0                0.00      0.00      0.01        0.01          0.04
# 1                0.00      0.00      0.01        0.01          0.06
# 2                0.00      0.01      0.01        0.02          0.05
# 3                0.00      0.01      0.01        0.02          0.05
# 4                0.00      0.01      0.01        0.02          0.06
# ..                ...       ...       ...         ...           ...
# 190              0.00      0.00      0.00        0.01          0.04
# 191              0.00      0.00      0.00        0.01          0.03
# 192              0.00      0.01      0.01        0.02          0.02
# 193              0.00      0.00      0.00        0.01          0.02
# 194              0.00      0.00      0.00        0.01          0.02
#
#      MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  NHR  \
# 0                0.43          0.02          0.03      0.03         0.07 0.02
# 1                0.63          0.03          0.05      0.04         0.09 0.02
# 2                0.48          0.03          0.04      0.04         0.08 0.01
# 3                0.52          0.03          0.04      0.04         0.09 0.01
# 4                0.58          0.03          0.05      0.04         0.10 0.02
# ..                ...           ...           ...       ...          ...  ...
# 190              0.41          0.02          0.02      0.03         0.07 0.03
# 191              0.26          0.02          0.02      0.02         0.05 0.02
# 192              0.26          0.01          0.01      0.02         0.04 0.11
# 193              0.24          0.01          0.01      0.02         0.04 0.07
# 194              0.19          0.01          0.01      0.01         0.03 0.04
#
#       HNR  status  RPDE  DFA  spread1  spread2   D2  PPE
# 0   21.03       1  0.41 0.82    -4.81     0.27 2.30 0.28
# 1   19.09       1  0.46 0.82    -4.08     0.34 2.49 0.37
# 2   20.65       1  0.43 0.83    -4.44     0.31 2.34 0.33
# 3   20.64       1  0.43 0.82    -4.12     0.33 2.41 0.37
# 4   19.65       1  0.42 0.82    -3.75     0.23 2.33 0.41
# ..    ...     ...   ...  ...      ...      ...  ...  ...
# 190 19.52       0  0.45 0.66    -6.54     0.12 2.66 0.13
# 191 19.15       0  0.43 0.68    -6.20     0.13 2.78 0.17
# 192 17.88       0  0.41 0.66    -6.79     0.16 2.68 0.13
# 193 19.02       0  0.45 0.64    -6.74     0.21 2.14 0.12
# 194 21.21       0  0.46 0.66    -5.72     0.19 2.56 0.15
#
# [195 rows x 24 columns]

# %%
df3.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df3.nunique()
# Out:
# name                195
# MDVP:Fo(Hz)         195
# MDVP:Fhi(Hz)        195
# MDVP:Flo(Hz)        195
# MDVP:Jitter(%)      173
# MDVP:Jitter(Abs)     19
# MDVP:RAP            155
# MDVP:PPQ            165
# Jitter:DDP          180
# MDVP:Shimmer        188
# MDVP:Shimmer(dB)    149
# Shimmer:APQ3        184
# Shimmer:APQ5        189
# MDVP:APQ            189
# Shimmer:DDA         189
# NHR                 185
# HNR                 195
# status                2
# RPDE                195
# DFA                 195
# spread1             195
# spread2             194
# D2                  195
# PPE                 195
# dtype: int64

# %%
df3.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
#  16  HNR               195 non-null    float64
#  17  status            195 non-null    int64
#  18  RPDE              195 non-null    float64
#  19  DFA               195 non-null    float64
#  20  spread1           195 non-null    float64
#  21  spread2           195 non-null    float64
#  22  D2                195 non-null    float64
#  23  PPE               195 non-null    float64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 36.7+ KB

# %%
# Column renaming dictionary
new_column_names = {
    'MDVP:Fo(Hz)': 'Median_Frequency_Hz',
    'MDVP:Fhi(Hz)': 'Max_Frequency_Hz',
    'MDVP:Flo(Hz)': 'Min_Frequency_Hz',
    'MDVP:Jitter(%)': 'Jitter_Percentage',
    'MDVP:Jitter(Abs)': 'Jitter_Absolute',
    'MDVP:RAP': 'Relative_Amplitude_Perturbation',
    'MDVP:PPQ': 'Period_Perturbation_Quotient',
    'Jitter:DDP': 'Jitter_DDP',
    'MDVP:Shimmer': 'Shimmer',
    'MDVP:Shimmer(dB)': 'Shimmer_dB',
    'Shimmer:APQ3': 'Amplitude_Perturbation_Quotient_3',
    'Shimmer:APQ5': 'Amplitude_Perturbation_Quotient_5',
    'MDVP:APQ': 'Amplitude_Perturbation_Quotient',
    'Shimmer:DDA': 'Shimmer_DDA',
    'NHR': 'Noise_to_Harmonics_Ratio',
    'HNR': 'Harmonics_to_Noise_Ratio',
    'status': 'Parkinson_Status',
    'RPDE': 'Recurrence_Period_Density_Entropy',
    'DFA': 'Detrended_Fluctuation_Analysis',
    'spread1': 'Frequency_Spread_1',
    'spread2': 'Frequency_Spread_2',
    'D2': 'Correlation_Dimension',
    'PPE': 'Pitch_Period_Entropy'
}

# Rename columns
df3.rename(columns=new_column_names, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Encode names into numeric values
encoder = LabelEncoder()
df3['name'] = encoder.fit_transform(df3['name'])

# %%
c = df3.drop(['Parkinson_Status'], axis=1)
d = df3['Parkinson_Status']

# %%
from sklearn.model_selection import train_test_split
c_train,c_test,d_train,d_test=train_test_split(c,d,test_size=0.2)
c_train.shape,c_test.shape,d_train.shape,d_test.shape
# Out:
# ((156, 23), (39, 23), (156,), (39,))

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier().fit(c_train,d_train)
d_pred=model.predict(c_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
print(classification_report(d_test,d_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95        11
#            1       0.97      1.00      0.98        28
#
#     accuracy                           0.97        39
#    macro avg       0.98      0.95      0.97        39
# weighted avg       0.98      0.97      0.97        39

# %%
from sklearn.ensemble import RandomForestClassifier
model1=RandomForestClassifier().fit(c_train,d_train)
d_pred=model1.predict(c_test)
print(classification_report(d_test,d_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90        11
#            1       0.93      1.00      0.97        28
#
#     accuracy                           0.95        39
#    macro avg       0.97      0.91      0.93        39
# weighted avg       0.95      0.95      0.95        39

# %%
from xgboost import XGBClassifier
model_parkinsons=XGBClassifier().fit(c_train,d_train)
d_pred=model_parkinsons.predict(c_test)
print(classification_report(d_test,d_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80        11
#            1       0.90      0.96      0.93        28
#
#     accuracy                           0.90        39
#    macro avg       0.89      0.85      0.87        39
# weighted avg       0.90      0.90      0.89        39

# %%
with(open('parkinsons.pkl','wb')) as file:
  pickle.dump(model_parkinsons,file)
